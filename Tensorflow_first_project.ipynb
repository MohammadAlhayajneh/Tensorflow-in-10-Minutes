# %% [markdown]
# <a href="https://colab.research.google.com/github/MohammadAlhayajneh/Tensorflow-in-10-Minutes/blob/main/Tensorflow_first_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 0. Import Data

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Churn.csv')
df.head()
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1            110.0
# 1                     26              161.6            123.0
# 2                      0              243.4            114.0
# 3                      0              299.4             71.0
# 4                      0              166.7            113.0
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4             99.0             16.78
# ...

# %%
df= df.dropna()
X = pd.get_dummies(df.drop(['Churn'], axis=1))
y = df['Churn'].apply(lambda x: 1 if x==True else 0)
y.head()
print(df["Churn"].value_counts())
print(y.value_counts())
# Out:
# Churn
# False    2827
# True      480
# Name: count, dtype: int64
# Churn
# 0    2827
# 1     480
# Name: count, dtype: int64

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.2)

# %%
y_train.head()
# Out:
# 1354    0
# 3282    0
# 1593    1
# 1899    0
# 2065    0
# Name: Churn, dtype: int64

# %% [markdown]
# # 1. Import Dependencies

# %%
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Dense
from sklearn.metrics import accuracy_score

# %% [markdown]
# # 2. Build and Compile Model

# %%
model= Sequential()
model.add(Dense(units=32, activation="relu", input_dim= len(X_train.columns)))
model.add(Dense(units=64, activation="relu"))
model.add(Dense(units=1, activation="sigmoid"))
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(loss="binary_crossentropy", optimizer="sgd", metrics=['accuracy'])

# %% [markdown]
# # 3. Fit, Predict and Evaluate

# %%
model.fit(X_train, y_train, epochs=200, batch_size=32)
# Out:
# Epoch 1/200
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7853 - loss: 11.5541
# Epoch 2/200
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8550 - loss: 0.5461
# Epoch 3/200
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8603 - loss: 0.4780
# Epoch 4/200
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8537 - loss: 0.4505
# Epoch 5/200
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8491 - loss: 0.4394
# Epoch 6/200
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8495 - loss: 0.4315
# Epoch 7/200
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8443 - loss: 0.4351
# Epoch 8/200
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8568 - loss: 0.4144
# Epoch 9/200
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8538 - loss: 0.4175
# Epoch 10/200
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8527 - loss: 0.4187
# Epoch 11/200
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8531 - loss: 0.4177
# Epoch 12/200
# ...

# %%
y_hat= model.predict(X_test)
y_hat= [0 if val<.5 else 1 for val in y_hat]
# Out:
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step

# %%
accuracy_score(y_test,y_hat)
# Out:
# 0.8700906344410876

# %% [markdown]
# # 4. Saving and Reloading

# %%
model.save('tfmodel.keras')

# %%
del model

# %%
model= load_model('tfmodel.keras')

# %%
model.predict(X_test)
# Out:
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# array([[0.00570952],
#        [0.15042712],
#        [0.15042712],
#        [0.15042712],
#        [0.15042712],
#        [0.15042712],
#        [0.15042712],
#        [0.15042712],
#        [0.15042712],
#        [0.15042712],
#        [0.15042712],
#        [0.15042712],
#        [0.15042712],
#        [0.15042712],
#        [0.15042712],
#        [0.15042712],
#        [0.15042712],
#        [0.15042712],
#        [0.15042712],
#        [0.15042712],
#        [0.15042712],
#        [0.15042712],
#        [0.15042712],
#        [0.15042712],
#        [0.15042712],
#        [0.15042712],
#        [0.15042712],
#        [0.15042712],
#        [0.15042712],
#        [0.15042712],
#        [0.15042712],
#        [0.15042712],
#        [0.15042712],
#        [0.15042712],
#        [0.15042712],
#        [0.15042712],
#        [0.15042712],
#        [0.15042712],
#        [0.15042712],
#        [0.15042712],
#        [0.02491384],
# ...
